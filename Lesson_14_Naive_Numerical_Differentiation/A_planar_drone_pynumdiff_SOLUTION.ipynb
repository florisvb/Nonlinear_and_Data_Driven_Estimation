# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

from scipy.integrate import odeint
import scipy.optimize

import sympy as sp

import pandas as pd

import copy

# %%
try:
  raise ValueError # <<<< force install until pypi is updated
  #import pynumdiff
except:
  # !pip install git+https://github.com/florisvb/PyNumDiff # <<<<<< use the latest version, not on pypi yet
  import pynumdiff
# Out:
# Collecting git+https://github.com/florisvb/PyNumDiff
#   Cloning https://github.com/florisvb/PyNumDiff to /tmp/pip-req-build-jez5fy8o
#   Running command git clone --filter=blob:none --quiet https://github.com/florisvb/PyNumDiff /tmp/pip-req-build-jez5fy8o
#   Resolved https://github.com/florisvb/PyNumDiff to commit ee5151aeead91c65f7459991b43e7782f6af4264
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pynumdiff==0.3.dev26+gee5151aee) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pynumdiff==0.3.dev26+gee5151aee) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pynumdiff==0.3.dev26+gee5151aee) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pynumdiff==0.3.dev26+gee5151aee) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pynumdiff==0.3.dev26+gee5151aee) (1.17.0)
# Building wheels for collected packages: pynumdiff
#   Building wheel for pynumdiff (pyproject.toml) ... done
#   Created wheel for pynumdiff: filename=pynumdiff-0.3.dev26+gee5151aee-py3-none-any.whl size=63872 sha256=7b912e30b7f77320d5b82ba57ec947cd52651846cef37020737779c5155e16d9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hscjt509/wheels/d5/d2/d5/e088d09db33998cc8a03da8ed5da944b4512c71615c0dc9e72
# Successfully built pynumdiff
# Installing collected packages: pynumdiff
# Successfully installed pynumdiff-0.3.dev26+gee5151aee

# %%
try:
    import casadi
except:
    # !pip install casadi
    import casadi

try:
    import do_mpc
except:
    # !pip install do_mpc
    import do_mpc

try:
    import pybounds
except:
    #!pip install pybounds
    # !pip install git+https://github.com/vanbreugel-lab/pybounds
    import pybounds
# Out:
# Collecting casadi
#   Downloading casadi-3.7.2-cp312-none-manylinux2014_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from casadi) (2.0.2)
# Downloading casadi-3.7.2-cp312-none-manylinux2014_x86_64.whl (75.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: casadi
# Successfully installed casadi-3.7.2
# Collecting do_mpc
#   Downloading do_mpc-5.0.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: casadi>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from do_mpc) (3.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from do_mpc) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from do_mpc) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from do_mpc) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from do_mpc) (2.2.2)
# Requirement already satisfied: torch>2.0.0 in /usr/local/lib/python3.12/dist-packages (from do_mpc) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>2.0.0->do_mpc) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->do_mpc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->do_mpc) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->do_mpc) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->do_mpc) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>2.0.0->do_mpc) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>2.0.0->do_mpc) (3.0.3)
# Downloading do_mpc-5.0.1-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.9/162.9 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: do_mpc
# Successfully installed do_mpc-5.0.1
# /usr/local/lib/python3.12/dist-packages/do_mpc/sysid/__init__.py:15: UserWarning: The ONNX feature is not available. Please install the full version of do-mpc to access this feature.
#   warnings.warn('The ONNX feature is not available. Please install the full version of do-mpc to access this feature.')
# /usr/local/lib/python3.12/dist-packages/do_mpc/opcua/__init__.py:14: UserWarning: The opcua feature is not available. Please install the full version of do-mpc to access this feature.
#   warnings.warn('The opcua feature is not available. Please install the full version of do-mpc to access this feature.')
# Collecting git+https://github.com/vanbreugel-lab/pybounds
#   Cloning https://github.com/vanbreugel-lab/pybounds to /tmp/pip-req-build-n8saol4t
#   Running command git clone --filter=blob:none --quiet https://github.com/vanbreugel-lab/pybounds /tmp/pip-req-build-n8saol4t
#   Resolved https://github.com/vanbreugel-lab/pybounds to commit 96f12039ac9e1e3ef4381cd09a026f6bbf70ad5c
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pybounds
#   Building wheel for pybounds (setup.py) ... done
#   Created wheel for pybounds: filename=pybounds-0.0.13-py3-none-any.whl size=19546 sha256=98ae4566dcf8739357705439e45893d6ccf3bd9d9cb90f090553764118336b50
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9ztsrke5/wheels/cb/f8/fb/ff1887f9a2f35c3edad7b1acb7da69437c1fd8d885a800578d
# Successfully built pybounds
# Installing collected packages: pybounds
# Successfully installed pybounds-0.0.13

# %% [markdown]
# ### Import plotting utilities and planar drone locally or from github

# %%
import sys
import requests
import importlib

def import_local_or_github(package_name, function_name=None, directory=None, giturl=None):
    # Import functions directly from github
    # Important: note that we use raw.githubusercontent.com, not github.com

    try: # to find the file locally
        if directory is not None:
            if directory not in sys.path:
                sys.path.append(directory)

        package = importlib.import_module(package_name)
        if function_name is not None:
            function = getattr(package, function_name)
            return function
        else:
            return package

    except: # get the file from github
        if giturl is None:
            giturl = 'https://raw.githubusercontent.com/florisvb/Nonlinear_and_Data_Driven_Estimation/main/Utility/' + str(package_name) + '.py'

        r = requests.get(giturl)
        print('Fetching from: ')
        print(r)

        # Store the file to the colab working directory
        with open(package_name+'.py', 'w') as f:
            f.write(r.text)
        f.close()

        # import the function we want from that file
        package = importlib.import_module(package_name)
        if function_name is not None:
            function = getattr(package , function_name)
            return function
        else:
            return package

planar_drone = import_local_or_github('planar_drone', directory='../Utility')
plot_tme = import_local_or_github('plot_utility', 'plot_tme', directory='../Utility')
# Out:
# Fetching from:
# <Response [200]>
# Fetching from:
# <Response [200]>

# %% [markdown]
# # Planar drone dynamics
#
# Now we will not include k as a static state. Instead, we will be using SINDy to find all the parameter values, which includes k.

# %% [markdown]
# #### Given the planar drone dynamics
#
# $
# \mathbf{\dot{x}} = \mathbf{f}(\mathbf{x},\mathbf{u}) =
# \frac{d}{dt}
# \begin{bmatrix}
# \bbox[yellow]{\theta} \\[0.3em]
# \bbox[yellow]{\dot{\theta}} \\[0.3em]
# \bbox[yellow]{x} \\[0.3em]
# \bbox[yellow]{\dot{x}} \\[0.3em]
# \bbox[yellow]{z} \\[0.3em]
# \bbox[yellow]{\dot{z}} \\[0.3em]
# \end{bmatrix} =
# \overset{f_0}{\begin{bmatrix}
# \bbox[yellow]{\dot{\theta}} \\[0.3em]
# 0 \\[0.3em]
# \bbox[yellow]{\dot{x}} \\[0.3em]
# 0 \\[0.3em]
# \bbox[yellow]{\dot{z}} \\[0.3em]
# -\bbox[lightblue]{g} \\[0.3em]
# \end{bmatrix}} +
# \overset{f_1}{\begin{bmatrix}
# 0 \\[0.3em]
# \bbox[lightblue]{l}\bbox[lightblue]{k}/\bbox[lightblue]{I_{yy}} \\[0.3em]
# 0 \\[0.3em]
# 0 \\[0.3em]
# 0 \\[0.3em]
# 0 \\[0.3em]
# \end{bmatrix}} \bbox[lightgreen]{j_1} +
# \overset{f_2}{\begin{bmatrix}
# 0 \\[0.3em]
# 0 \\[0.3em]
# 0 \\[0.3em]
# -\bbox[lightblue]{k}\bbox[yellow]{\sin\theta}/\bbox[lightblue]{m} \\[0.3em]
# 0 \\[0.3em]
# \bbox[lightblue]{k}\bbox[yellow]{\cos\theta}/\bbox[lightblue]{m}  \\[0.3em]
# \end{bmatrix}} \bbox[lightgreen]{j_2}
# $
#
# #### Consider the following scenario
#
# We have made measurements of $x$, and we want to know $\dot{x}$. Pretend we know nothing else.

# %% [markdown]
# # Dynamics and measurement functions
#
# Here we will use versions of `f` and `h` that do not consider $k$ to be a state.

# %%
f = planar_drone.F(k=1).f
h = planar_drone.H('h_camera_imu', k=1).h

# %%
print(f(None, None, return_state_names=True))
# Out:
# ['theta', 'theta_dot', 'x', 'x_dot', 'z', 'z_dot']

# %%
print(h(None, None, return_measurement_names=True))
# Out:
# ['optic_flow', 'theta', 'theta_dot', 'accel_x', 'accel_z']

# %% [markdown]
# # Run MPC simulation
#
# Let's use a more dynamic (``random``) trajectory now, and enforce smoother control inputs with a larger `rterm`.

# %%
dt = 0.1
tsim_length = 20
tsim = np.arange(0, tsim_length, step=dt)

# %%
t_sim, x_sim, u_sim, y_sim, simulator = planar_drone.simulate_drone(f, h=h, dt=dt, tsim_length=tsim_length,
                                                                    trajectory_shape='random',
                                                                    rterm=1e-1)

# %% [markdown]
# ### Plot the x, z trajectory

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x_sim['x'], x_sim['z'])

ax.set_xlabel('x pos')
ax.set_ylabel('z pos')
# Out:
# Text(0, 0.5, 'z pos')

# %%
x_sim_df = pd.DataFrame(x_sim)
u_sim_df = pd.DataFrame(u_sim)

# %% [markdown]
# # Now add a little noise and pretend we have real data

# %%
noise_std = 0.3
state_x_noisy = x_sim_df['x'] + np.random.normal(0, noise_std, len(x_sim_df['x']))

# %%
plot_tme(t_sim, x_sim_df['x'], state_x_noisy, None, label_var='x')
# Out:
# <Axes: xlabel='Time', ylabel='x'>

# %% [markdown]
# # Compute naive numerical derivatives
#
# There are many ways to do this. Here are few common methods -- when properly tuned, it does not matter which one you use.
#   * First order finite difference: just calculate difference between neighboring points
#   * Savitzky Golay filter: frequency domain sliding polynomial fit
#   * Spectral derivative: take a derivative in the frequency domain
#   * Total variation regularization: balance accuracy and variation

# %% [markdown]
# ### First Order Finite Difference
#
# Serves as motivation to use other methods.
#
# Note: if you apply iterations, the results are actually quite good. Use second or fourth order to remove delay.

# %%
fd = pynumdiff.finite_difference.first_order
state_x_smooth, state_xdot_smooth = fd(state_x_noisy.values, dt, num_iterations=1)
plot_tme(t_sim, x_sim_df['x'], state_x_noisy, state_x_smooth, label_var='x')
plot_tme(t_sim, x_sim_df['x_dot'], None, state_xdot_smooth, label_var='x_dot')
# Out:
# <Axes: xlabel='Time', ylabel='x_dot'>

# %% [markdown]
# ### Savitzy Golay Filter
#
# Frequency domain sliding polynomial fit. Great option, very fast and simple.

# %%
state_x_smooth, state_xdot_smooth = pynumdiff.savgoldiff(state_x_noisy, dt, degree=3, window_size=7, smoothing_win=7)
plot_tme(t_sim, x_sim_df['x'], state_x_noisy, state_x_smooth, label_var='x')
plot_tme(t_sim, x_sim_df['x_dot'], None, state_xdot_smooth, label_var='x_dot')
# Out:
# <Axes: xlabel='Time', ylabel='x_dot'>

# %% [markdown]
# ### Spectral Derivative
#
# Take a derivative in the frequency domain

# %%
specdiff = pynumdiff.basis_fit.spectraldiff
state_x_smooth, state_xdot_smooth = specdiff(state_x_noisy.values, dt, even_extension=True,
                                             pad_to_zero_dxdt=True, high_freq_cutoff=0.085)
plot_tme(t_sim, x_sim_df['x'], state_x_noisy, state_x_smooth, label_var='x')
plot_tme(t_sim, x_sim_df['x_dot'], None, state_xdot_smooth, label_var='x_dot')
# Out:
# <Axes: xlabel='Time', ylabel='x_dot'>

# %% [markdown]
# ### Total Variation Regularization
#
# Finds a derivative that balances two goals:
# 1. The integral of the derivative should match the original signal.
# 2. The total variation of the derivative should be small (i.e. there should be minimal changes in the derivative from step to step).
#
# Note: if you have cvxpy installed, and access to the cvxpy license (free for academic email), you can use a convex optimization implementation of TVR, and you can regularize the acceleration or jerk to get smoother derivatives.

# %%
tvr = pynumdiff.total_variation_regularization.iterative_velocity
state_x_smooth, state_xdot_smooth = tvr(state_x_noisy, dt, num_iterations=2, gamma=0.1)
plot_tme(t_sim, x_sim_df['x'], state_x_noisy, state_x_smooth, label_var='x')
plot_tme(t_sim, x_sim_df['x_dot'], None, state_xdot_smooth, label_var='x_dot')
# Out:
# <Axes: xlabel='Time', ylabel='x_dot'>

# %% [markdown]
# # Exercises:
#
# 1. Change the parameters of some of the methods above to get some intution as to their effect.
# 2. Choose a method. Plot the following metrics for a number of different parameter choices:
#      * Root Mean Squared Error for the derivative estimates:
# $RMSE = \sqrt{ \sum_{i=0}^{N} (\hat{\dot{x}}_i - \dot{x}_i)^2 / N }$.
#      * Error Correlation: Pearson's correlation coefficient ($R^2$). Hint: look up `scipy.stats.linregress`.
# 3. What are the implications of a high RMSE? What about a high Error Correlation?

# %% [markdown]
# # Solution

# %%
error = state_xdot_smooth - x_sim_df['x_dot']

# %%
scipy.stats.linregress(error, x_sim_df['x_dot']).rvalue**2
# Out:
# np.float64(0.4489173143630956)

# %%
plt.plot(error, x_sim_df['x_dot'], '.')
plt.xlabel('true derivative')
plt.ylabel('error')
# Out:
# Text(0, 0.5, 'error')

# %%
RMSE = []
ErrCorr = []

specdiff = pynumdiff.basis_fit.spectraldiff

freq_cutoffs = np.linspace(0.001, 0.99)
for f in freq_cutoffs:
    state_x_smooth, state_xdot_smooth = specdiff(state_x_noisy.values, dt, even_extension=True,
                                                pad_to_zero_dxdt=True, high_freq_cutoff=f)
    error = state_xdot_smooth - x_sim_df['x_dot']
    rmse = np.sqrt(np.mean(error**2))
    RMSE.append(rmse)

    err_corr = scipy.stats.linregress(error, x_sim_df['x_dot']).rvalue**2
    ErrCorr.append(err_corr)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(RMSE, ErrCorr, '.')
ax.set_xscale('log')

ax.set_xlabel('log(RMSE)')
ax.set_ylabel('Error Correlation')
# Out:
# Text(0, 0.5, 'Error Correlation')
